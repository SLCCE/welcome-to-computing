# %% [markdown]
# # Try printing the following figures!

# %% [markdown]
# ```
#   /\
#  /  \
# /____\
# ```

# %% [markdown]
# ```
#   ___
#  /   \
# /     \
# \     /
#  \___/
# ```

# %%
# Triangle
print("  /\\\n /  \\\n/____\\")
# Out:
#   /\
#  /  \
# /____\

# %%
# Hexagon
print("  ___\n /   \\\n/     \\\n\\     /\n \\___/")
# Out:
#   ___
#  /   \
# /     \
# \     /
#  \___/
