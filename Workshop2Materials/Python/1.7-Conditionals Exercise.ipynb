# %% [markdown]
# # Conditionals Exercise
#
# ## Predicting Output
#
# *In this exercise, you have to predict what the output for a given input and conditional block will print. Enter you answer into the empty string and then run the code block, if the two match, you are correct!*

# %%
monthNumber = 8

if monthNumber == 0:
    month = "January"
elif monthNumber == 1:
    month = "February"
elif monthNumber == 2:
    month = "March"
elif monthNumber == 3:
    month = "April"
elif monthNumber == 4:
    month = "May"
elif monthNumber == 5:
    month = "June"
elif monthNumber == 6:
    month = "July"
elif monthNumber == 7:
    month = "August"
elif monthNumber == 8:
    month = "September"
elif monthNumber == 9:
    month = "October"
elif monthNumber == 10:
    month = "November"
elif monthNumber == 11:
    month = "December"

print(month)

#Replace the empty string with your answer
answer = ""
print(answer)

# %%
monthNumber = 2

if monthNumber == 0:
    month = "January"
elif monthNumber == 1:
    month = "February"
elif monthNumber == 2:
    month = "March"
elif monthNumber == 3:
    month = "April"
elif monthNumber == 4:
    month = "May"
elif monthNumber == 5:
    month = "June"
elif monthNumber == 6:
    month = "July"
elif monthNumber == 7:
    month = "August"
elif monthNumber == 8:
    month = "September"
elif monthNumber == 9:
    month = "October"
elif monthNumber == 10:
    month = "November"
elif monthNumber == 11:
    month = "December"

print(month)

#Replace the empty string with your answer
answer = ""
print(answer)

# %%
monthNumber = 11

if monthNumber == 0:
    month = "January"
elif monthNumber == 1:
    month = "February"
elif monthNumber == 2:
    month = "March"
elif monthNumber == 3:
    month = "April"
elif monthNumber == 4:
    month = "May"
elif monthNumber == 5:
    month = "June"
elif monthNumber == 6:
    month = "July"
elif monthNumber == 7:
    month = "August"
elif monthNumber == 8:
    month = "September"
elif monthNumber == 9:
    month = "October"
elif monthNumber == 10:
    month = "November"
elif monthNumber == 11:
    month = "December"

print(month)

#Replace the empty string with your answer
answer = ""
print(answer)

# %%
monthNumber = 5

if monthNumber == 0:
    month = "January"
elif monthNumber == 1:
    month = "February"
elif monthNumber == 2:
    month = "March"
elif monthNumber == 3:
    month = "April"
elif monthNumber == 4:
    month = "May"
elif monthNumber == 5:
    month = "June"
elif monthNumber == 6:
    month = "July"
elif monthNumber == 7:
    month = "August"
elif monthNumber == 8:
    month = "September"
elif monthNumber == 9:
    month = "October"
elif monthNumber == 10:
    month = "November"
elif monthNumber == 11:
    month = "December"

print(month)

#Replace the empty string with your answer
answer = ""
print(answer)

# %%
direction = "right"
item = "sword"

if direction == "left":
    
    if item == "pen":
        
        print("You run into a lion and fail to defeat it")
        
    else:  #If it is not pen, then it is sword
        
        print("Your trusty sword helps you defeat the lion")
        
else:  #If it is not left, then it is right
    
    if item == "pen":
        
        print("You find a blank sheet of paper and start writing a book")
        
    else:  #If it is not pen, then it is sword
        
        print("You slice the sheet of paper into confetti")

#Replace the empty string with your answer
answer = ""
print(answer)

# %%
direction = "left"
item = "sword"

if direction == "left":
    
    if item == "pen":
        
        print("You run into a lion and fail to defeat it")
        
    else:  #If it is not pen, then it is sword
        
        print("Your trusty sword helps you defeat the lion")
        
else:  #If it is not left, then it is right
    
    if item == "pen":
        
        print("You find a blank sheet of paper and start writing a book")
        
    else:  #If it is not pen, then it is sword
        
        print("You slice the sheet of paper into confetti")

#Replace the empty string with your answer
answer = ""
print(answer)

# %%
direction = "right"
item = "pen"

if direction == "left":

    if item == "pen":

        print("You run into a lion and fail to defeat it")

    else:  #If it is not pen, then it is sword

        print("Your trusty sword helps you defeat the lion")

else:  #If it is not left, then it is right

    if item == "pen":

        print("You find a blank sheet of paper and start writing a book")

    else:  #If it is not pen, then it is sword

        print("You slice the sheet of paper into confetti")

#Replace the empty string with your answer
answer = ""
print(answer)

# %%
direction = "left"
item = "pen"

if direction == "left":

    if item == "pen":

        print("You run into a lion and fail to defeat it")

    else:  #If it is not pen, then it is 
        
        print("Your trusty sword helps you defeat the lion")
        
else:  #If it is not left, then it is right
    
    if item == "pen":
        
        print("You find a blank sheet of paper and start writing a book")
        
    else:  #If it is not pen, then it is sword
        
        print("You slice the sheet of paper into confetti")
        

#Replace the empty string with your answer
answer = ""
print(answer)

# %%
number = 4

remainder = number % 2
    
if remainder == 0:

    label = "Even"

else:
    
    label = "Odd"

print(label)

#Replace the empty string with your answer
answer = ""
print(answer)

# %%
x = 3
y = 7

if x + y > 10:

    print("The sum is greater than 10")

elif x + y == 10:

    print("The sum is exactly 10")

else:
    
    print("The sum is less than 10")


#Replace the empty string with your answer
answer = ""
print(answer)

# %%
x = 2
y = 10

if x + y > 10:

    print("The sum is greater than 10")

elif x + y == 10:

    print("The sum is exactly 10")

else:
    
    print("The sum is less than 10")


#Replace the empty string with your answer
answer = ""
print(answer)

# %%
x = 9
y = -4

if x + y > 10:

    print("The sum is greater than 10")

elif x + y == 10:

    print("The sum is exactly 10")

else:
    
    print("The sum is less than 10")


#Replace the empty string with your answer
answer = ""
print(answer)

# %% [markdown]
# ## Now It's Your Turn!
#
# *In the space below, create a program that uses conditionals to check if one number is bigger than the other or if they are equal. The program uses two variables: x and y. If x is bigger than y, print "x is bigger than y". If y is bigger than x, print "y is bigger than x". If x and y are equal, print "x and y are equal".

# %%
#Choose values for x and y
x = 
y = 

#Create your conditional here
